# %% [markdown]
# # K Means
# The most simple clustering model.
# # Unsupervised dataset
# We want to understand paterns in the data.<br>
# We will split a large dataset, that doesn't have a targer, to N datasets – D1, D2, D2…

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# Load the dataset

# %%
df = pd.read_csv("../../Datasets/kmeans.csv")
df.head(1)
# Out:
#           A         B         C         D        E         F         G
# 0  9.671602  3.097308 -4.400873  1.634558 -2.65029 -5.042444  7.960961

# %% [markdown]
# ## Create the Model

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=4) # n_clusyers - the number of the mini datasets we want to split our dataset to.

# %% [markdown]
# ## Train the Model
# Send the dataset to the model

# %%
model.fit(df)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# ## Watch the results with a scatter

# %%
plt.scatter(df['C'],df['B'],c=model.labels_,cmap='rainbow')

# %% [markdown]
# ## Test the Model
# Predict a new data to see to which group the model will put it.

# %%
kmeans.predict(np.array([-10,-10]).reshape(1,-1))

# %% [markdown]
# ## Information about the Model

# %%
model.cluster_centers_
# Out:
# array([[ 7.68299355,  4.34312399, -6.05315895,  1.22505718, -2.9182865 ,
#         -6.36025366,  6.04110337],
#        [ 0.52394079,  1.40593768, -9.38544092, -6.58121286,  3.81246035,
#          6.66136388, -3.77224517],
#        [ 0.5040399 , -8.79395338, -7.47222041, -6.41373703,  9.81807285,
#          0.45755849,  1.66464092],
#        [ 9.25393672, -5.27269708, -8.39652632,  2.0281954 ,  4.7615351 ,
#         -4.33634035,  3.69957797]])
